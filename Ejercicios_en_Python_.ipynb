# %% [markdown]
# <a href="https://colab.research.google.com/github/Luisa802/PROGCOM-A/blob/main/Ejercicios_en_Python_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #5.Crea un programa que resuelva una ecuación cuadrática (ax² + bx + c = 0) pidiendo los valores de a, b y c.

# %%
import math
a = float(input("Ingrese el valor de a: "))
b = float(input("Ingrese el valor de b: "))
c = float(input("Ingrese el valor de c: "))
if a==0:
  print("El valor de 'a' no puede ser cero en la ecuacion")
else:
  discriminante= b**2-4*a*c
if discriminante > 0:
  x1=(-b + math.sqrt(discriminante)) / (2*a)
  x2=(-b - math.sqrt(discriminante)) / (2*a)
  print("las soluciones de la ecuacion son:")
  print("x1 =", x1)
  print("x2 =", x2)

elif discriminante == 0:
    x=-b / (2*a)
    print(f" la unica solucion de la ecuacion es:")
    print("x=", x)

else:
      print("la ecuacion no tiene soluciones en los reales, su discriminate es negativo ")
# Out:
# Ingrese el valor de a: 2
# Ingrese el valor de b: 8
# Ingrese el valor de c: 3
# las soluciones de la ecuacion son:
# x1 = -0.41886116991581024
# x2 = -3.58113883008419

# %%
import math

print("Ecuación cuadrática ax^2 + bx + c = 0")

a = float(input("Ingrese a: "))
b = float(input("Ingrese b: "))
c = float(input("Ingrese c: "))
if a == 0:
    print("No es una ecuación cuadrática")
else:
    d = b*b - 4*a*c
    if d < 0:
        print("No tiene soluciones reales")
    else:
        x1 = (-b + math.sqrt(d)) / (2*a)
        x2 = (-b - math.sqrt(d)) / (2*a)
        print("Las soluciones son:")
        print("x1 =", x1)
        print("x2 =", x2)
# Out:
# Ecuación cuadrática ax^2 + bx + c = 0
# Ingrese a: 8
# Ingrese b: 2
# Ingrese c: 4
# No tiene soluciones reales

# %%
import math

print("Ecuación cuadrática ax^2 + bx + c = 0")

a = float(input("Ingrese a: "))
b = float(input("Ingrese b: "))
c = float(input("Ingrese c: "))

resp= "No es una ecuación cuadrática" if a == 0 else "No tiene soluciones reales" if d < 0 else "Las soluciones son:"
print(resp)
# Out:
# Ecuación cuadrática ax^2 + bx + c = 0
# Ingrese a: 2
# Ingrese b: 8
# Ingrese c: 3
# No tiene soluciones reales

# %% [markdown]
# #6.Desarrolla un programa que determine si un número es par o impar.

# %%
numero = int(input("Ingrese un número: "))
if numero % 2 == 0:
    print(f"El número {numero} es par")
else:
    print(f"El número {numero} es impar")
# Out:
# Ingrese un número: 2
# El número 2 es par

# %%
numero = int(input("Ingrese un número: "))
if numero % 2 == 0:
    print(f"El número {numero} es par")
else:
    if numero % 2 != 0:
        print(f"El número {numero} es impar")
# Out:
# Ingrese un número: 7
# El número 7 es impar

# %%
numero = int(input("Ingrese un número: "))
resp= "El número es par" if numero % 2 == 0 else "El número es impar"
print(resp)
# Out:
# Ingrese un número: 25
# El número es impar

# %% [markdown]
# #7. Crea un programa que determine si un año es bisiesto (divisible por 4 y no por 100, o divisible por 400).

# %%
año=int(input("Ingrese el año:"))
if año % 4 ==0:
  print("El año ingresado es bisiesto")
elif año % 400 ==0:
  print("El año es bisiesto")
else:
  print(f"El año ingresado {año} no es bisiesto")
# Out:
# ingrese el año:2026
# el año ingresado 2026 no es bisiesto

# %%
año=int(input("Ingrese el año:"))
if año % 4 ==0:
  print("El año ingresado es bisiesto")
else:
  if año % 400 ==0:
    print("El año es bisiesto")
  else:
    print(f"El año ingresado {año} no es bisiesto")
# Out:
# Ingrese el año:2025
# El año ingresado 2025 no es bisiesto

# %%
resp= "El año ingresado es bisiesto" if año % 4 ==0 else "El año es bisiesto" if año % 400 ==0 else "El año ingresado no es bisiesto"
print(resp)
# Out:
# El año ingresado no es bisiesto

# %% [markdown]
# #8. Escribe un programa que solicite el nombre del usuario y determine si una persona pertenece a la tercera edad (70 años o más) y si se cumple la condición, imprima que se le da prioridad en la fila.

# %%
nombre = input("Por favor, ingresa tu nombre: ")
edad = int(input("Ingresa tu edad: "))

if edad >= 70:
    print(f"Hola {nombre}, perteneces a la tercera edad.")
    print("Tienes prioridad en la fila.")
elif edad >= 18:
    print(f"Hola {nombre}. Usted es mayor de edad, por favor haga la fila regular.")

else:
    print(f"Hola {nombre}. Eres menor de edad, por favor espera a tu tutor.")
# Out:
# Por favor, ingresa tu nombre: Luisa
# Ingresa tu edad: 18
# Hola Luisa. Usted es mayor de edad, por favor haga la fila regular.

# %%
nombre = input("Ingresa tu nombre: ")
edad = int(input("Ingresa tu edad: "))

if edad >= 70:
    print(f"Bienvenido/a {nombre}.")
    print("Usted tiene prioridad en la fila por pertenecer a la tercera edad.")
else:
    print(f"Hola {nombre}. Por favor, espere su turno en la fila general.")
# Out:
# Ingresa tu nombre: Leonor
# Ingresa tu edad: 43
# Hola Leonor. Por favor, espere su turno en la fila general.

# %%
edad = int(input("Ingresa tu edad: "))
resp="Usted tiene prioridad en la fila por pertenecer a la tercera edad."if edad >= 70 else "Por favor, espere su turno en la fila general."
print(resp)
# Out:
# Ingresa tu edad: 75
# Usted tiene prioridad en la fila por pertenecer a la tercera edad.

# %% [markdown]
# #9. Desarrolla un programa que compare tres números y muestre el mayor.

# %%
numero1 = float(input("Ingresa el primer número: "))
numero2 = float(input("Ingresa el segundo número: "))
numero3 = float(input("Ingresa el tercer número: "))

if numero1 > numero2 and numero1 > numero3:
    print("El numero mayor es:", numero1)
elif numero2 > numero1 and numero2 > numero3:
    print("El numero mayor es:", numero2)
elif numero3 > numero1 and numero3 > numero2:
    print("El número mayor es:", numero3)
else:
    print("Hay numeros iguales o los tres son iguales")
# Out:
# Ingresa el primer número: 3
# Ingresa el segundo número: 4
# Ingresa el tercer número: 7
# El número mayor es: 7.0

# %%
numero1 = float(input("Ingresa el primer número: "))
numero2 = float(input("Ingresa el segundo número: "))
numero3 = float(input("Ingresa el tercer número: "))

mayor = numero1

if numero2 > mayor:
    mayor = numero2
else:
    mayor = mayor

if numero3 > mayor:
    mayor = numero3
else:
    mayor = mayor
print("El número mayor es:", mayor)
# Out:
# Ingresa el primer número: 5
# Ingresa el segundo número: 9
# Ingresa el tercer número: 5
# El número mayor es: 9.0

# %%
numero1 = float(input("Ingrese el primer número: "))
numero2 = float(input("Ingrese el segundo número: "))
numero3 = float(input("Ingrese el tercer número: "))

mayor = numero1 if numero1 > numero2 else numero2
mayor = mayor if mayor > numero3 else numero3

print("El número mayor es:", mayor)
# Out:
# Ingrese el primer número: 1
# Ingrese el segundo número: 1
# Ingrese el tercer número: 1
# El número mayor es: 1.0

# %% [markdown]
# #10. Crea un programa que determine si un triángulo es equilátero, isósceles o escaleno según sus lados.

# %%
lado1=int(input("Ingrese el primer lado del triangulo: "))
lado2=int(input("Ingrese el segundo lado del triangulo: "))
lado3=int(input("Ingrese el tercer lado del triangulo: "))
if lado1==lado2==lado3:
  print("Es un triangulo equilatero")
elif lado1==lado2 or lado1==lado3 or lado2==lado3:
  print("Es un triangulo isoceles")
else:
  print("Es un triangulo escaleno")
# Out:
# Ingrese el primer lado del triangulo: 20
# Ingrese el segundo lado del triangulo: 5
# Ingrese el tercer lado del triangulo: 8
# Es un triangulo escaleno

# %%
lado1=int(input("Ingrese el primer lado del triangulo: "))
lado2=int(input("Ingrese el segundo lado del triangulo: "))
lado3=int(input("Ingrese el tercer lado del triangulo: "))
if lado1==lado2==lado3:
  print("Es un triangulo equilatero")
else:
  if lado1==lado2 or lado1==lado3 or lado2==lado3:
    print("Es un triangulo isoceles")
  else:
    print("Es un triangulo escaleno")
# Out:
# Ingrese el primer lado del triangulo: 7
# Ingrese el segundo lado del triangulo: 7
# Ingrese el tercer lado del triangulo: 7
# Es un triangulo equilatero

# %%
lado1=int(input("Ingrese el primer lado del triangulo: "))
lado2=int(input("Ingrese el segundo lado del triangulo: "))
lado3=int(input("Ingrese el tercer lado del triangulo: "))

resp="Es un triangulo equilatero" if lado1==lado2==lado3 else "Es un triangulo isoceles" if lado1==lado2 or lado1==lado3 or lado2==lado3 else "Es un triangulo escaleno"
print(resp)
# Out:
# Ingrese el primer lado del triangulo: 3
# Ingrese el segundo lado del triangulo: 6
# Ingrese el tercer lado del triangulo: 3
# Es un triangulo isoceles

# %% [markdown]
# #11. Escribe un programa que calcule el índice de masa corporal (IMC) y determine la categoría (bajo peso, normal, sobrepeso, obesidad). Al final, el programa debe imprimir: el nombre del usuario, su categoría y una breve descripción de lo que debe hacer de acuerdo a su categoría.

# %%
peso=float(input("Ingrese su peso kg: "))
altura=float(input("Ingrese su estatura m: "))
imc=peso/(altura**2)
print(f"Este es su IMC {imc:.2f}")
if imc<18.5:
  print("Tiene bajo peso")
elif 18.5<imc<24.9:
  print("Tiene peso normal")
elif 25<imc<29.9:
  print("Tiene sobrepeso")
else:
  print("Tiene obesidad")
# Out:
# Ingrese su peso kg: 50
# Ingrese su estatura m: 1.56
# Este es su IMC 20.55
# Tiene peso normal

# %%
peso=float(input("Ingrese su peso kg: "))
altura=float(input("Ingrese su estatura m: "))
imc=peso/(altura**2)
print(f"Este es su IMC {imc:.2f}")
if imc<18.5:
  print("Tiene bajo peso")
else:
  if 18.5<imc<24.9:
    print("Tiene peso normal")
  else:
    if 25<imc<29.9:
      print("Tiene sobrepeso")
    else:
      print("Tiene obesidad")
# Out:
# Ingrese su peso kg: 40
# Ingrese su estatura m: 1.60
# Este es su IMC 15.62
# Tiene bajo peso

# %%
peso=float(input("Ingrese su peso kg: "))
altura=float(input("Ingrese su estatura m: "))
imc=peso/(altura**2)
print(f"Este es su IMC {imc:.2f}")

resp="Tiene bajo peso" if imc<18.5 else "Tiene peso normal" if 18.5<imc<24.9 else "Tiene sobrepeso" if 25<imc<29.9 else "Tiene obesidad"
print(resp)
# Out:
# Ingrese su peso kg: 104
# Ingrese su estatura m: 1.80
# Este es su IMC 32.10
# Tiene obesidad

# %% [markdown]
# #12. Desarrolla un programa que simule una calculadora simple (+, -, *, /) con dos números.

# %%
numero1 = float(input("Ingresa el primer número: "))
numero2 = float(input("Ingresa el segundo número: "))
operacion = input("Ingrese la operación que desea realizar: ")

if operacion == "+":
    resultado = numero1 + numero2
    print("El resultado es:", resultado)

elif operacion == "-":
    resultado = numero1 - numero2
    print("El resultado es:", resultado)

elif operacion == "*":
    resultado = numero1 * numero2
    print("El resultado es:", resultado)

elif operacion == "/":
    if numero2 != 0:
        resultado = numero1 / numero2
        print("El resultado es:", resultado)
    else:
        print("No se puede dividir entre cero")

else:
   print("Operación no válida")
# Out:
# Ingresa el primer número: 9
# Ingresa el segundo número: 10
# Ingrese la operación que desea realizar: +
# El resultado es: 19.0

# %%
numero1 = float(input("Ingresa el primer número: "))
numero2 = float(input("Ingresa el segundo número: "))
operacion = input("Ingrese la operación que desea realizar: ")

if operacion == "+":
    print("Resultado:", numero1 + numero2)
else:
    if operacion == "-":
        print("Resultado:", numero1 - numero2)
    else:
        if operacion == "*":
            print("Resultado:", numero1 * numero2)
        else:
            if operacion == "/":
                if numero2 != 0:
                    print("Resultado:", numero1 / numero2)
                else:
                    print("No se puede dividir entre cero")
            else:
                print("Operación no válida")
# Out:
# Ingresa el primer número: 7
# Ingresa el segundo número: 6
# Ingrese la operación que desea realizar: *
# Resultado: 42.0

# %%
numero1 = float(input("Ingresa el primer número: "))
numero2 = float(input("Ingresa el segundo número: "))
operacion = input("Ingrese la operación que desea realizar: ")

resp= ("Resultado:", numero1 + numero2) if operacion == "+" else ("Resultado:", numero1 - numero2) if operacion == "-" else ("Resultado:", numero1 * numero2) if operacion == "*" else ("Resultado:", numero1 / numero2) if operacion == "/" else "Operación no válida" if operacion != "+" and operacion != "-" and operacion != "*" and operacion != "/" else "No se puede dividir entre cero"
print(resp)
# Out:
# Ingresa el primer número: 8
# Ingresa el segundo número: 2
# Ingrese la operación que desea realizar: /
# ('Resultado:', 4.0)

# %% [markdown]
# # 13. Crea un programa que determine la calificación en letras (A, B, C, D, F) según una nota numérica (0-100).

# %%
nota=int(input("Ingrese su nota: "))
if nota>=90:
  print("Su nota tiene una A 😄")
elif nota>=80:
  print("Su nota tiene una B 😊")
elif nota>=70:
  print("Su nota tiene una C 🙂")
elif nota>=60:
  print("Su nota tiene una D 🙁")
else:
  print("Su nota tiene una F 😖")
# Out:
# Ingrese su nota: 10
# Su nota tiene una F 😖

# %%
nota=int(input("Ingrese su nota: "))
if nota>=90:
  print("Su nota tiene una A 😄")
else:
  if nota>=80:
    print("Su nota tiene una B 😊")
  else:
    if nota>=70:
      print("Su nota tiene una C 🙂")
    else:
      if nota>=60:
        print("Su nota tiene una D 🙁")
      else:
        print("Su nota tiene una F 😖")
# Out:
# Ingrese su nota: 80
# Su nota tiene una B 😊

# %%
nota=int(input("Ingrese su nota: "))

resp= "Su nota tiene una A 😄" if nota>=90 else "Su nota tiene una B 😊" if nota>=80 else "Su nota tiene una C 🙂" if nota>=70 else "Su nota tiene una D 🙁" if nota>=60 else "Su nota tiene una F 😖"
print(resp)
# Out:
# Ingrese su nota: 76
# Su nota tiene una C 🙂

# %% [markdown]
# #14. Escribe un programa que determine el día de la semana según un número (1-7).

# %%
num=int(input("Ingrese un número del 1 al 7 para determinar que día de la semana es: "))
if num==1:
  print("El día es Lunes")
elif num==2:
  print("El día es Martes")
elif num==3:
  print("El día es Miércoles")
elif num==4:
  print("EL día es Jueves")
elif num==5:
  print("El día es viernes")
elif num==6:
  print("El día es Sábado")
else:
  print("El día es Domingo")
# Out:
# Ingrese un número del 1 al 7 para determinar que día de la semana es: 4
# EL día es Jueves

# %%
num=int(input("Ingrese un número del 1 al 7 para determinar que día de la semana es: "))
if num==1:
  print("El día es Lunes")
else:
  if num==2:
    print("El día es Martes")
  else:
    if num==3:
      print("El día es Miércoles")
    else:
      if num==4:
        print("EL día es Jueves")
      else:
        if num==5:
          print("El día es viernes")
        else:
          if num==6:
            print("El día es Sábado")
          else:
            print("El día es Domingo")
# Out:
# Ingrese un número del 1 al 7 para determinar que día de la semana es: 1
# El día es Lunes

# %%
num=int(input("Ingrese un número del 1 al 7 para determinar que día de la semana es: "))
resp="El día es Lunes" if num==1 else "El día es Martes" if num==2 else "El día es Miércoles" if num==3 else "EL día es Jueves" if num==4 else "El día es viernes" if num==5 else "El día es Sábado" if num==6 else "El día es Domingo"
print(resp)
# Out:
# Ingrese un número del 1 al 7 para determinar que día de la semana es: 6
# El día es Sábado

# %% [markdown]
# #15. Desarrolla un programa que valide si tres números pueden formar un triángulo y de qué tipo es.

# %%
a = float(input("Ingrese el primer lado: "))
b = float(input("Ingrese el segundo lado: "))
c = float(input("Ingrese el tercer lado: "))

if a == b == c:
    print("El triangulo es equilatero")

elif a == b or b == c or a == c:
    print("El triangulo es isosceles")

elif a + b > c and a + c > b and b + c > a:
    print("El triangulo es escaleno")

else:
    print("Los lados ingresados no forman un triangulo")
# Out:
# Ingrese el primer lado: 5
# Ingrese el segundo lado: 6
# Ingrese el tercer lado: 6
# El triangulo es isosceles

# %%
a = float(input("Ingrese el primer lado: "))
b = float(input("Ingrese el segundo lado: "))
c = float(input("Ingrese el tercer lado: "))

if a + b > c and a + c > b and b + c > a:

    if a == b and b == c:
        print("El triangulo es equilatero")
    else:
        if a == b or a == c or b == c:
            print("El triangulo es isosceles")
        else:
            print("El triangulo es escaleno")

else:
    print("Los lados ingresados no forman un triangulo")
# Out:
# Ingrese el primer lado: 8
# Ingrese el segundo lado: 8
# Ingrese el tercer lado: 8
# El triangulo es equilatero

# %%
a = float(input("Ingrese el primer lado: "))
b = float(input("Ingrese el segundo lado: "))
c = float(input("Ingrese el tercer lado: "))

resp= "El triangulo es equilatero" if a == b == c else "El triangulo es isosceles" if a == b or b == c or a == c else "El triangulo es escaleno" if a + b > c and a + c > b and b + c > a else "Los lados ingresados no forman un triangulo"
print(resp)
# Out:
# Ingrese el primer lado: 5
# Ingrese el segundo lado: 9
# Ingrese el tercer lado: 8
# El triangulo es escaleno

# %% [markdown]
# <a href="https://colab.research.google.com/github/Luisa802/PROGCOM-A/blob/main/Continuaci%C3%B3n_Listas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
comida=["combo 1", "combo 2", "combo 3", "combo 4", "Papas", "jugos naturales", "cerveza", "agua", "Gaseosa" ]
precios=[20000,25000,18000,24500,3000,7000,3500,4000,2500]

# %%
for menu in range(len(comida)):
  print(comida[menu], "-", precios[menu])
# Out:
# combo 1 - 20000
# combo 2 - 25000
# combo 3 - 18000
# combo 4 - 24500
# Papas - 3000
# jugos naturales - 7000
# Cerveza - 3500
# Agua - 4000
# Gaseosa - 2500

# %%
a=0
r="s"
user="s"
while user=="s":
  while r=="s":
    x=input("Qué desea ordenar?: ")
    if x=="combo 1": a=a+20000
    elif x=="combo 2": a=a+25000
    elif x=="combo 3": a=a+18000
    elif x=="combo 4": a=a+24500
    elif x=="Papas": a=a+3000
    elif x=="jugos naturales": a=a+7000
    elif x=="Cerveza": a=a+3500
    elif x=="Agua": a=a+4000
    elif x=="Gaseosa": a=a+2500
    else:
      x=input("Desea algo más?")
      if x=="s": continue
      else: break
  user=input("Hay más usuarios?: ")
print(f"Usted ha ganado ${a} en el día")
# Out:
# Qué desea ordenar?: combo 2
# Qué desea ordenar?: combo 4
# Qué desea ordenar?: combo 1
# Qué desea ordenar?: jugo
# Desea algo más?si
# Hay más usuarios?: si
# Usted ha ganado $69500 en el día

# %%
a=0
r="si"
user="si"
while user=="si":
  while r=="si":
    x=input("Qué desea ordenar?: ")
    if x in comida:
      cantidad = int(input(f"¿Cuántas unidades de {x} desea ordenar?: "))
      a = a + precios[comida.index(x)] * cantidad
    else:
      print("No esta ese producto")
    while True:
      x=input("Desea algo más? (si/no): ").lower()
      if x in ["si", "no"]:
        break
      else:
        print("Por favor, ingrese 'si' o 'no'.")

    if x=="si": continue
    else: break
  user=input("Hay más usuarios?: ").lower()
print(f"Usted ha ganado ${a} en el día")
# Out:
# Qué desea ordenar?: combo 1
# ¿Cuántas unidades desea ordenar?: 2
# Desea algo más? (si/no): p
# Por favor, ingrese 'si' o 'no'.
# Desea algo más? (si/no): si
# Qué desea ordenar?: agua
# ¿Cuántas unidades desea ordenar?: 1
# Desea algo más? (si/no): no
# Hay más usuarios?: no
# Usted ha ganado $44000 en el día

# %% [markdown]
# #FUNCIÓN
#
# Es un pedazo de código que su ejecuta aparte. Aveces se conoce como copiado dinámico.
#
# Ventajas de implementar las funciones
# 1. Veulve el código más limpio
# 2. Elimina el código wspaguetti
# 3. Establece un orden de búsqueda
# 4. Permite reutilización del código
#
# Sintaxix
# ````
# def nombre_de_la_función (parametros):
#  Aqui va todo lo que desees ejecutar
#  return algo
# ````
#
# Existen 4 tipos de funciones
# 1. Sin parámetro, sin retorno
# 2. Sin parámetro, con retorno
# 3. Con parámetro, sin retorno
# 4. Con parámetro, con retorno

# %%
#Sin parámetro, sin retorno
def menu():
  #preci y comi son variables locales
  comi=["combo 1", "combo 2", "combo 3", "combo 4", "Papas", "jugos naturales", "cerveza", "agua", "Gaseosa" ]
  preci=[20000,25000,18000,24500,3000,7000,3500,4000,2500]
  for menu in range(len(comi)):
    print(comi[menu], "-", preci[menu])

# %%
#Sin parámetro, sin retorno
menu()
# Out:
# combo 1 - 20000
# combo 2 - 25000
# combo 3 - 18000
# combo 4 - 24500
# Papas - 3000
# jugos naturales - 7000
# cerveza - 3500
# agua - 4000
# Gaseosa - 2500

# %%
a=0
r="s"
user="s"
while user=="s":
  while r=="s":
    menu()
    x=input("Qué desea ordenar?: ")
    if x in comida:
      cantidad = int(input(f"¿Cuántas unidades de {x} desea ordenar?: "))
      a = a + precios[comida.index(x)] * cantidad
    else:
      x=input("Desea algo más?")
      if x=="s": continue
      else: break
  user=input("Hay más usuarios?: ")
print(f"Usted ha ganado ${a} en el día")
# Out:
# combo 1 - 20000
# combo 2 - 25000
# combo 3 - 18000
# combo 4 - 24500
# Papas - 3000
# jugos naturales - 7000
# cerveza - 3500
# agua - 4000
# Gaseosa - 2500
# Qué desea ordenar?: no
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_534/4196857285.py in <cell line: 0>()
#       6     menu()
#       7     x=input("Qué desea ordenar?: ")
# ----> 8     if x in comida:
#       9       cantidad = int(input(f"¿Cuántas unidades de {x} desea ordenar?: "))
#      10       a = a + precios[comida.index(x)] * cantidad
#
# NameError: name 'comida' is not defined

# %%
#Sin parámetro, con retorno
def saludo():
  nombre=input("Hola. Comó te llamas?")
  return f"Hola {nombre}. Gusto en saludarte"

# %%
saludo()
# Out:
# Hola. Comó te llamas?Luisa
# 'Hola Luisa. Gusto en saludarte'

# %%
#Con parámetro, con retorno
def saludo_venganza(nombre):
  return f"Hola {nombre}. Gusto en saludarte"

# %%
saludo_venganza("luisa")
# Out:
# 'Hola luisa. Gusto en saludarte'

# %%
#Con parámetro sin retorno
def saludo(nombre):
  print(f"Hola {nombre}. Gusto en saludarte")

# %%
saludo("Luisa")
# Out:
# Hola Luisa. Gusto en saludarte

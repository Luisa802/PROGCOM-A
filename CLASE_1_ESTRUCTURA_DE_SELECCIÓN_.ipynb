# %% [markdown]
# <a href="https://colab.research.google.com/github/Luisa802/PROGCOM-A/blob/main/CLASE_1_ESTRUCTURA_DE_SELECCI%C3%93N_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Estructura de selección
# Evalúan una condición de verdad.
#
# 1. IF/ELSE
# 2. IF TERNARIO
# 2. IF/ELIF/ELSE
# 4. CASE

# %% [markdown]
# 1. IF/ELSE
# Sólo tiene dos posibles respuestas (V) o (F)
# Sintaxis
# ````
# If (condición):
#  aquí se ejecuta código **si** la condición es verdadera.
#
# else:
#  aquí de ejecuta el código **si** la condición es falsa.
#
# ````

# %%
lluvia=input("Está lloviendo? ")
if lluvia=="no":
  print("Te recomiendo ir al parque")
else:
  if lluvia=="un poquito":
    print("Te sugiro que si vas al parque lleva sombrilla ")
  else:
    if lluvia=="si":
      print("Cierra las ventanas")
    else:
      print("resguárdese")
# Out:
# Está lloviendo? si con tormenta
# resguárdese
